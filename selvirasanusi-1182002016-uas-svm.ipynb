# %%
library(e1071)

# %%
data <- read.csv("../input/uas-svm/UAS_SVM-1.csv", header = TRUE, sep = ";")

# %%
head(data)
# Out:
#   Customer.ID Age Income Education Occupation Income.1 Average.Balance
# 1 1234561427  5   2      4         5          2        2
# 2 1234561518  3   3      4         2          2        4
# 3 1234561282  1   4      4         2          4        2
# 4 1234561064  4   4      2         2          1        4
# 5 1234561043  1   1      4         1          1        4
# 6 1234561619  1   4      3         3          1        2
#   Appraisal Industri Pelunasan.Kredit
# 1 2         1        1
# 2 2         4        0
# 3 1         3        1
# 4 4         2        0
# 5 5         3        1
# 6 1         2        1

# %%
dim(data)
# Out:
# [1] 999  10

# %%
n=round(nrow(data)*0.70)

# %%
n
# Out:
# [1] 699

# %%
set.seed(23456)

# %%
sample=sample(seq_len(nrow(data)), size = n)

# %%
train=data[sample, ]

# %%
dim(train)
# Out:
# [1] 699  10

# %%
test=data[-sample, ]

# %%
dim(test)
# Out:
# [1] 300  10

# %%
data.svm<-svm(factor(Pelunasan.Kredit) ~., data = train, probability=T)

# %%
head(data.svm)
# Out:
# $call
# svm(formula = factor(Pelunasan.Kredit) ~ ., data = train, probability = T)
#
# $type
# [1] 0
#
# $kernel
# [1] 2
#
# $cost
# [1] 1
#
# $degree
# [1] 3
#
# $gamma
# [1] 0.1111111

# %%
prediks1 <- predict(data.svm, train, decision.values=T, probability=T)

# %%
head(prediks1)
# Out:
# 915  37 108 431 152  43
#   1   1   1   1   1   1
# Levels: 0 1

# %%
confusionMatrix(factor(train$Pelunasan.Kredit), factor(prediks1))
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction   0   1
#          0 218 124
#          1  73 284
#
#                Accuracy : 0.7182
#                  95% CI : (0.6832, 0.7513)
#     No Information Rate : 0.5837
#     P-Value [Acc > NIR] : 1.102e-13
#
#                   Kappa : 0.4343
#
#  Mcnemar's Test P-Value : 0.0003675
#
#             Sensitivity : 0.7491
#             Specificity : 0.6961
#          Pos Pred Value : 0.6374
#          Neg Pred Value : 0.7955
#              Prevalence : 0.4163
#          Detection Rate : 0.3119
#    Detection Prevalence : 0.4893
#       Balanced Accuracy : 0.7226
#
#        'Positive' Class : 0

# %%
prediks1 <- predict(data.svm, test, decision.values=T, probability=T)

# %%
head(prediks1)
# Out:
#  1  3  7  9 14 15
#  1  1  1  0  1  1
# Levels: 0 1

# %%
confusionMatrix(factor(test$Pelunasan.Kredit), factor(prediks1))
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction  0  1
#          0 48 86
#          1 77 89
#
#                Accuracy : 0.4567
#                  95% CI : (0.3993, 0.5149)
#     No Information Rate : 0.5833
#     P-Value [Acc > NIR] : 1.0000
#
#                   Kappa : -0.1063
#
#  Mcnemar's Test P-Value : 0.5309
#
#             Sensitivity : 0.3840
#             Specificity : 0.5086
#          Pos Pred Value : 0.3582
#          Neg Pred Value : 0.5361
#              Prevalence : 0.4167
#          Detection Rate : 0.1600
#    Detection Prevalence : 0.4467
#       Balanced Accuracy : 0.4463
#
#        'Positive' Class : 0
